# %% [markdown]
# # 03_05: Wordplay Challenge Solution

# %%
import math
import collections
import itertools

import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %matplotlib inline

# %%
words = sorted({line.strip().lower() for line in open('words.txt', 'r')})

# %%
# code from 03_03_findinganagrams #треба знайти слова - які мають зворотні аналоги (букви навпаки с кінця в початок)

def signature(word):
    return ''.join(sorted(word))

words_by_sig = collections.defaultdict(set)

for word in words:
    words_by_sig[signature(word)].add(word)
    
anagrams_by_sig = {sig: wordset for sig, wordset in words_by_sig.items() if len(wordset) > 1}

# %%
# reverse word by slicing with negative step 
'michele'[::-1]
# Out:
# 'elehcim'

# %%
# loop over anagram sets, and over all possible pairs of words in each set:
# if the second word equals the reverse of the first, add pair to list

# цикл по наборах анаграм і по всіх можливих парах слів у кожному наборі:
# якщо друге слово дорівнює зворотному до першого, додати пару до списку

pairs = []

for wordset in anagrams_by_sig.values():
    for word1 in wordset:
        for word2 in wordset:  
            # consider only sorted pairs to avoid duplicate matches
            if word1 >= word2 and word1[::-1] == word2:
                pairs.append((word1, word2))

# %%
pairs
# Out:
# [('ala', 'ala'),
#  ('ama', 'ama'),
#  ('ba', 'ab'),
#  ('aba', 'aba'),
#  ('caba', 'abac'),
#  ('saba', 'abas'),
#  ('bab', 'bab'),
#  ('abba', 'abba'),
#  ('yalb', 'blay'),
#  ('isba', 'absi'),
#  ('tuba', 'abut'),
#  ('araca', 'acara'),
#  ('acca', 'acca'),
#  ('dirca', 'acrid'),
#  ('da', 'ad'),
#  ('adda', 'adda'),
#  ('dada', 'adad'),
#  ('rada', 'adar'),
#  ('dad', 'dad'),
#  ('duad', 'daud'),
#  ('teda', 'adet'),
#  ('naid', 'dian'),
#  ('namda', 'adman'),
#  ('oda', 'ado'),
#  ('yard', 'dray'),
#  ('yad', 'day'),
#  ('ea', 'ae'),
#  ('rea', 'aer'),
#  ('era', 'are'),
#  ('sea', 'aes'),
#  ('alga', 'agla'),
#  ('amaga', 'agama'),
#  ('raga', 'agar'),
#  ('regga', 'agger'),
#  ('biga', 'agib'),
#  ('morga', 'agrom'),
#  ('tsuga', 'agust'),
#  ('ha', 'ah'),
#  ('moha', 'ahom'),
#  ('tha', 'aht'),
#  ('redia', 'aider'),
#  ('elia', 'aile'),
#  ('ima', 'ami'),
#  ('ria', 'air'),
#  ('aria', 'aira'),
#  ('eria', 'aire'),
#  ('ita', 'ati'),
#  ('raja', 'ajar'),
#  ('ka', 'ak'),
#  ('akka', 'akka'),
#  ('oka', 'ako'),
#  ('kua', 'auk'),
#  ('la', 'al'),
#  ('lana', 'anal'),
#  ('lab', 'bal'),
#  ('nabla', 'alban'),
#  ('nabal', 'laban'),
#  ('mela', 'alem'),
#  ('nael', 'lean'),
#  ('lina', 'anil'),
#  ('yalla', 'allay'),
#  ('ella', 'alle'),
#  ('muilla', 'allium'),
#  ('amla', 'alma'),
#  ('lamina', 'animal'),
#  ('dola', 'alod'),
#  ('lowa', 'awol'),
#  ('pal', 'lap'),
#  ('tal', 'lat'),
#  ('ma', 'am'),
#  ('apama', 'amapa'),
#  ('rama', 'amar'),
#  ('diorama', 'amaroid'),
#  ('samas', 'samas'),
#  ('massa', 'assam'),
#  ('enema', 'amene'),
#  ('ulema', 'amelu'),
#  ('nema', 'amen'),
#  ('mane', 'enam'),
#  ('xema', 'amex'),
#  ('decima', 'amiced'),
#  ('lima', 'amil'),
#  ('naim', 'mian'),
#  ('rima', 'amir'),
#  ('amma', 'amma'),
#  ('maam', 'maam'),
#  ('soma', 'amos'),
#  ('tam', 'mat'),
#  ('manuma', 'amunam'),
#  ('yam', 'may'),
#  ('na', 'an'),
#  ('ana', 'ana'),
#  ('aracana', 'anacara'),
#  ('mana', 'anam'),
#  ('anna', 'anna'),
#  ('nana', 'anan'),
#  ('asana', 'anasa'),
#  ('tana', 'anat'),
#  ('yana', 'anay'),
#  ('edna', 'ande'),
#  ('rogan', 'nagor'),
#  ('sina', 'anis'),
#  ('sain', 'nias'),
#  ('nan', 'nan'),
#  ('manna', 'annam'),
#  ('nona', 'anon'),
#  ('tan', 'nat'),
#  ('etna', 'ante'),
#  ('taen', 'neat'),
#  ('tuan', 'naut'),
#  ('yan', 'nay'),
#  ('trapa', 'apart'),
#  ('dopa', 'apod'),
#  ('tap', 'pat'),
#  ('supa', 'apus'),
#  ('ra', 'ar'),
#  ('bara', 'arab'),
#  ('read', 'daer'),
#  ('sagra', 'argas'),
#  ('regal', 'lager'),
#  ('rial', 'lair'),
#  ('rail', 'liar'),
#  ('lira', 'aril'),
#  ('kra', 'ark'),
#  ('ram', 'mar'),
#  ('ran', 'nar'),
#  ('ora', 'aro'),
#  ('sarra', 'arras'),
#  ('tracer', 'recart'),
#  ('sirrah', 'harris'),
#  ('tar', 'rat'),
#  ('tra', 'art'),
#  ('sumatra', 'artamus'),
#  ('ura', 'aru'),
#  ('mura', 'arum'),
#  ('yar', 'ray'),
#  ('rayan', 'nayar'),
#  ('lyra', 'aryl'),
#  ('sa', 'as'),
#  ('asa', 'asa'),
#  ('kasa', 'asak'),
#  ('mesa', 'asem'),
#  ('sark', 'kras'),
#  ('rosa', 'asor'),
#  ('ta', 'at'),
#  ('ata', 'ata'),
#  ('pata', 'atap'),
#  ('tae', 'eat'),
#  ('eta', 'ate'),
#  ('seta', 'ates'),
#  ('pita', 'atip'),
#  ('sita', 'atis'),
#  ('salta', 'atlas'),
#  ('teal', 'laet'),
#  ('tael', 'leat'),
#  ('lakota', 'atokal'),
#  ('laud', 'dual'),
#  ('ulua', 'aulu'),
#  ('etua', 'aute'),
#  ('lava', 'aval'),
#  ('eva', 'ave'),
#  ('diva', 'avid'),
#  ('siva', 'avis'),
#  ('ova', 'avo'),
#  ('wa', 'aw'),
#  ('tawa', 'awat'),
#  ('wad', 'daw'),
#  ('wan', 'naw'),
#  ('noxa', 'axon'),
#  ('ya', 'ay'),
#  ('haya', 'ayah'),
#  ('cab', 'bac'),
#  ('dab', 'bad'),
#  ('gab', 'bag'),
#  ('mab', 'bam'),
#  ('nab', 'ban'),
#  ('knab', 'bank'),
#  ('rab', 'bar'),
#  ('brab', 'barb'),
#  ('drab', 'bard'),
#  ('sab', 'bas'),
#  ('stab', 'bats'),
#  ('tab', 'bat'),
#  ('kitab', 'batik'),
#  ('wab', 'baw'),
#  ('deb', 'bed'),
#  ('dieb', 'beid'),
#  ('treble', 'elbert'),
#  ('neb', 'ben'),
#  ('reb', 'ber'),
#  ('dib', 'bid'),
#  ('gib', 'big'),
#  ('mib', 'bim'),
#  ('nib', 'bin'),
#  ('drib', 'bird'),
#  ('sib', 'bis'),
#  ('tib', 'bit'),
#  ('bulb', 'blub'),
#  ('cabob', 'bobac'),
#  ('boob', 'boob'),
#  ('dob', 'bod'),
#  ('doob', 'bood'),
#  ('gob', 'bog'),
#  ('rohob', 'bohor'),
#  ('obol', 'lobo'),
#  ('mob', 'bom'),
#  ('nob', 'bon'),
#  ('knob', 'bonk'),
#  ('pob', 'bop'),
#  ('rob', 'bor'),
#  ('rerob', 'borer'),
#  ('gorb', 'brog'),
#  ('sob', 'bos'),
#  ('wob', 'bow'),
#  ('garb', 'brag'),
#  ('yarb', 'bray'),
#  ('yerb', 'brey'),
#  ('trub', 'burt'),
#  ('turb', 'brut'),
#  ('tuber', 'rebut'),
#  ('dub', 'bud'),
#  ('nub', 'bun'),
#  ('knub', 'bunk'),
#  ('rub', 'bur'),
#  ('drub', 'burd'),
#  ('grub', 'burg'),
#  ('rubor', 'robur'),
#  ('suber', 'rebus'),
#  ('sub', 'bus'),
#  ('tub', 'but'),
#  ('ecad', 'dace'),
#  ('lac', 'cal'),
#  ('mac', 'cam'),
#  ('sumac', 'camus'),
#  ('pac', 'cap'),
#  ('paced', 'decap'),
#  ('recap', 'pacer'),
#  ('wac', 'caw'),
#  ('spec', 'ceps'),
#  ('tic', 'cit'),
#  ('talc', 'clat'),
#  ('laced', 'decal'),
#  ('doc', 'cod'),
#  ('orc', 'cro'),
#  ('roc', 'cor'),
#  ('soc', 'cos'),
#  ('marc', 'cram'),
#  ('eruc', 'cure'),
#  ('gad', 'dag'),
#  ('sgad', 'dags'),
#  ('had', 'dah'),
#  ('laid', 'dial'),
#  ('radek', 'kedar'),
#  ('lad', 'dal'),
#  ('mad', 'dam'),
#  ('nomad', 'damon'),
#  ('nidal', 'ladin'),
#  ('pad', 'dap'),
#  ('rad', 'dar'),
#  ('farad', 'daraf'),
#  ('grad', 'darg'),
#  ('ranid', 'dinar'),
#  ('strad', 'darts'),
#  ('trader', 'redart'),
#  ('retrad', 'darter'),
#  ('sad', 'das'),
#  ('rated', 'detar'),
#  ('ed', 'de'),
#  ('meed', 'deem'),
#  ('peed', 'deep'),
#  ('reed', 'deer'),
#  ('ged', 'deg'),
#  ('led', 'del'),
#  ('fled', 'delf'),
#  ('timed', 'demit'),
#  ('ned', 'den'),
#  ('hoped', 'depoh'),
#  ('tressed', 'dessert'),
#  ('leud', 'duel'),
#  ('lived', 'devil'),
#  ('wed', 'dew'),
#  ('rewed', 'dewer'),
#  ('yed', 'dey'),
#  ('id', 'di'),
#  ('morbid', 'dibrom'),
#  ('reid', 'dier'),
#  ('tide', 'edit'),
#  ('gid', 'dig'),
#  ('olid', 'dilo'),
#  ('mid', 'dim'),
#  ('timid', 'dimit'),
#  ('nid', 'din'),
#  ('enid', 'dine'),
#  ('sid', 'dis'),
#  ('tid', 'dit'),
#  ('od', 'do'),
#  ('dod', 'dod'),
#  ('ode', 'edo'),
#  ('god', 'dog'),
#  ('lod', 'dol'),
#  ('elod', 'dole'),
#  ('mod', 'dom'),
#  ('nod', 'don'),
#  ('lood', 'dool'),
#  ('mood', 'doom'),
#  ('redoom', 'mooder'),
#  ('rood', 'door'),
#  ('pod', 'dop'),
#  ('rod', 'dor'),
#  ('prod', 'dorp'),
#  ('sod', 'dos'),
#  ('tod', 'dot'),
#  ('wod', 'dow'),
#  ('liard', 'drail'),
#  ('ward', 'draw'),
#  ('reward', 'drawer'),
#  ('warder', 'redraw'),
#  ('word', 'drow'),
#  ('gud', 'dug'),
#  ('mud', 'dum'),
#  ('pud', 'dup'),
#  ('nae', 'ean'),
#  ('notice', 'eciton'),
#  ('lee', 'eel'),
#  ('ere', 'ere'),
#  ('ree', 'eer'),
#  ('loge', 'egol'),
#  ('he', 'eh'),
#  ('eke', 'eke'),
#  ('spale', 'elaps'),
#  ('nifle', 'elfin'),
#  ('haole', 'eloah'),
#  ('noel', 'leon'),
#  ('lone', 'enol'),
#  ('spole', 'elops'),
#  ('seel', 'lees'),
#  ('revel', 'lever'),
#  ('me', 'em'),
#  ('lime', 'emil'),
#  ('mime', 'emim'),
#  ('remi', 'imer'),
#  ('rime', 'emir'),
#  ('time', 'emit'),
#  ('mem', 'mem'),
#  ('ume', 'emu'),
#  ('ne', 'en'),
#  ('romane', 'enamor'),
#  ('reman', 'namer'),
#  ('fine', 'enif'),
#  ('wone', 'enow'),
#  ('esne', 'ense'),
#  ('yoven', 'nevoy'),
#  ('sope', 'epos'),
#  ('re', 'er'),
#  ('reg', 'ger'),
#  ('reen', 'neer'),
#  ('sore', 'eros'),
#  ('retier', 'reiter'),
#  ('seer', 'rees'),
#  ('se', 'es'),
#  ('nave', 'evan'),
#  ('eve', 'eve'),
#  ('neve', 'even'),
#  ('reve', 'ever'),
#  ('live', 'evil'),
#  ('ewe', 'ewe'),
#  ('ye', 'ey'),
#  ('eye', 'eye'),
#  ('nye', 'eyn'),
#  ('raif', 'fiar'),
#  ('reef', 'feer'),
#  ('lief', 'feil'),
#  ('nef', 'fen'),
#  ('if', 'fi'),
#  ('gif', 'fig'),
#  ('welf', 'flew'),
#  ('golf', 'flog'),
#  ('wolf', 'flow'),
#  ('wolfer', 'reflow'),
#  ('of', 'fo'),
#  ('ofo', 'ofo'),
#  ('loof', 'fool'),
#  ('stoof', 'foots'),
#  ('orf', 'fro'),
#  ('refer', 'refer'),
#  ('jag', 'gaj'),
#  ('lag', 'gal'),
#  ('mag', 'gam'),
#  ('nag', 'gan'),
#  ('nagnag', 'gangan'),
#  ('tang', 'gnat'),
#  ('rag', 'gar'),
#  ('rang', 'gnar'),
#  ('sag', 'gas'),
#  ('tag', 'gat'),
#  ('retag', 'gater'),
#  ('wag', 'gaw'),
#  ('wang', 'gnaw'),
#  ('zag', 'gaz'),
#  ('leg', 'gel'),
#  ('redleg', 'gelder'),
#  ('meg', 'gem'),
#  ('seg', 'ges'),
#  ('teg', 'get'),
#  ('mig', 'gim'),
#  ('nig', 'gin'),
#  ('pig', 'gip'),
#  ('trig', 'girt'),
#  ('tig', 'git'),
#  ('og', 'go'),
#  ('log', 'gol'),
#  ('reflog', 'golfer'),
#  ('nog', 'gon'),
#  ('rog', 'gor'),
#  ('sog', 'gos'),
#  ('tog', 'got'),
#  ('upgo', 'ogpu'),
#  ('lug', 'gul'),
#  ('plug', 'gulp'),
#  ('mug', 'gum'),
#  ('pug', 'gup'),
#  ('rug', 'gur'),
#  ('trug', 'gurt'),
#  ('tug', 'gut'),
#  ('makah', 'hakam'),
#  ('nallah', 'hallan'),
#  ('mah', 'ham'),
#  ('pah', 'hap'),
#  ('trah', 'hart'),
#  ('wah', 'haw'),
#  ('yah', 'hay'),
#  ('reh', 'her'),
#  ('oh', 'ho'),
#  ('pooh', 'hoop'),
#  ('poh', 'hop'),
#  ('obi', 'ibo'),
#  ('immi', 'immi'),
#  ('ni', 'in'),
#  ('retin', 'niter'),
#  ('tennis', 'sinnet'),
#  ('nori', 'iron'),
#  ('kori', 'irok'),
#  ('si', 'is'),
#  ('sisi', 'isis'),
#  ('ti', 'it'),
#  ('neti', 'iten'),
#  ('tier', 'reit'),
#  ('timo', 'omit'),
#  ('raj', 'jar'),
#  ('taj', 'jat'),
#  ('nak', 'kan'),
#  ('panak', 'kanap'),
#  ('tanak', 'kanat'),
#  ('lark', 'kral'),
#  ('yak', 'kay'),
#  ('kayak', 'kayak'),
#  ('leek', 'keel'),
#  ('peek', 'keep'),
#  ('seek', 'kees'),
#  ('pik', 'kip'),
#  ('polk', 'klop'),
#  ('pank', 'knap'),
#  ('nark', 'kran'),
#  ('rank', 'knar'),
#  ('tink', 'knit'),
#  ('tonk', 'knot'),
#  ('tunk', 'knut'),
#  ('ok', 'ko'),
#  ('rok', 'kor'),
#  ('sok', 'kos'),
#  ('rauk', 'kuar'),
#  ('mal', 'lam'),
#  ('nopal', 'lapon'),
#  ('plap', 'palp'),
#  ('sural', 'larus'),
#  ('sal', 'las'),
#  ('sail', 'lias'),
#  ('ossal', 'lasso'),
#  ('peel', 'leep'),
#  ('reel', 'leer'),
#  ('teel', 'leet'),
#  ('repel', 'leper'),
#  ('relap', 'paler'),
#  ('rel', 'ler'),
#  ('relevel', 'leveler'),
#  ('rivel', 'levir'),
#  ('neil', 'lien'),
#  ('mil', 'lim'),
#  ('nil', 'lin'),
#  ('noil', 'lion'),
#  ('sunil', 'linus'),
#  ('sil', 'lis'),
#  ('til', 'lit'),
#  ('well', 'llew'),
#  ('olam', 'malo'),
#  ('siol', 'lois'),
#  ('mool', 'loom'),
#  ('pool', 'loop'),
#  ('tool', 'loot'),
#  ('retool', 'looter'),
#  ('pol', 'lop'),
#  ('tol', 'lot'),
#  ('owl', 'lwo'),
#  ('nam', 'man'),
#  ('senam', 'manes'),
#  ('oam', 'mao'),
#  ('pam', 'map'),
#  ('tram', 'mart'),
#  ('sam', 'mas'),
#  ('stam', 'mats'),
#  ('teem', 'meet'),
#  ('teemer', 'remeet'),
#  ('timer', 'remit'),
#  ('retem', 'meter'),
#  ('wem', 'mew'),
#  ('ohm', 'mho'),
#  ('saim', 'mias'),
#  ('nim', 'min'),
#  ('rim', 'mir'),
#  ('om', 'mo'),
#  ('sloom', 'mools'),
#  ('room', 'moor'),
#  ('toom', 'moot'),
#  ('pom', 'mop'),
#  ('tom', 'mot'),
#  ('yom', 'moy'),
#  ('um', 'mu'),
#  ('sum', 'mus'),
#  ('ym', 'my'),
#  ('rohan', 'nahor'),
#  ('zaman', 'namaz'),
#  ('pan', 'nap'),
#  ('susan', 'nasus'),
#  ('redden', 'nedder'),
#  ('peen', 'neep'),
#  ('teen', 'neet'),
#  ('pen', 'nep'),
#  ('repen', 'neper'),
#  ('ten', 'net'),
#  ('oven', 'nevo'),
#  ('wen', 'new'),
#  ('pin', 'nip'),
#  ('tin', 'nit'),
#  ('on', 'no'),
#  ('tenon', 'nonet'),
#  ('poon', 'noop'),
#  ('ron', 'nor'),
#  ('ton', 'not'),
#  ('won', 'now'),
#  ('yon', 'noy'),
#  ('un', 'nu'),
#  ('tun', 'nut'),
#  ('tao', 'oat'),
#  ('senones', 'senones'),
#  ('top', 'pot'),
#  ('ro', 'or'),
#  ('tor', 'rot'),
#  ('yor', 'roy'),
#  ('so', 'os'),
#  ('oto', 'oto'),
#  ('toot', 'toot'),
#  ('otto', 'otto'),
#  ('suto', 'otus'),
#  ('wo', 'ow'),
#  ('repaper', 'repaper'),
#  ('rap', 'par'),
#  ('trap', 'part'),
#  ('tarp', 'prat'),
#  ('taps', 'spat'),
#  ('wap', 'paw'),
#  ('yap', 'pay'),
#  ('rep', 'per'),
#  ('rip', 'pir'),
#  ('tip', 'pit'),
#  ('pulp', 'plup'),
#  ('toop', 'poot'),
#  ('troper', 'report'),
#  ('tops', 'spot'),
#  ('toper', 'repot'),
#  ('wop', 'pow'),
#  ('turp', 'prut'),
#  ('up', 'pu'),
#  ('sup', 'pus'),
#  ('tup', 'put'),
#  ('sar', 'ras'),
#  ('war', 'raw'),
#  ('rewarder', 'redrawer'),
#  ('teer', 'reet'),
#  ('sier', 'reis'),
#  ('tinker', 'reknit'),
#  ('tenner', 'rennet'),
#  ('retter', 'retter'),
#  ('terret', 'terret'),
#  ('rever', 'rever'),
#  ('tewer', 'rewet'),
#  ('venator', 'rotanev'),
#  ('sur', 'rus'),
#  ('tur', 'rut'),
#  ('was', 'saw'),
#  ('twas', 'sawt'),
#  ('taws', 'swat'),
#  ('yas', 'say'),
#  ('wes', 'sew'),
#  ('yes', 'sey'),
#  ('sis', 'sis'),
#  ('wels', 'slew'),
#  ('wots', 'stow'),
#  ('traps', 'spart'),
#  ('sus', 'sus'),
#  ('tuts', 'stut'),
#  ('yaws', 'sway'),
#  ('vat', 'tav'),
#  ('wat', 'taw'),
#  ('yat', 'tay'),
#  ('teet', 'teet'),
#  ('wet', 'tew'),
#  ('trot', 'tort'),
#  ('wot', 'tow'),
#  ('yot', 'toy'),
#  ('wort', 'trow'),
#  ('ut', 'tu'),
#  ('yaw', 'way'),
#  ('yew', 'wey'),
#  ('yow', 'woy')]

# %%
import itertools

# %%
# list all combinations of two different elements from the set {1,2,3} 
# перерахувати всі комбінації двох різних елементів із набору {1,2,3}


list(itertools.combinations({1,2,3}, 2))
# Out:
# [(1, 2), (1, 3), (2, 3)]

# %%
# same as above, using itertools.combinations to generate unique pairs

pairs = []

for wordset in anagrams_by_sig.values():
    for word1, word2 in itertools.combinations(wordset, 2):
        if word1[::-1] == word2:
            pairs.append((word1, word2))

# %%
pairs
# Out:
# [('ba', 'ab'),
#  ('abac', 'caba'),
#  ('saba', 'abas'),
#  ('yalb', 'blay'),
#  ('absi', 'isba'),
#  ('abut', 'tuba'),
#  ('acara', 'araca'),
#  ('acrid', 'dirca'),
#  ('ad', 'da'),
#  ('adad', 'dada'),
#  ('rada', 'adar'),
#  ('duad', 'daud'),
#  ('adet', 'teda'),
#  ('dian', 'naid'),
#  ('adman', 'namda'),
#  ('ado', 'oda'),
#  ('dray', 'yard'),
#  ('yad', 'day'),
#  ('ea', 'ae'),
#  ('rea', 'aer'),
#  ('era', 'are'),
#  ('sea', 'aes'),
#  ('alga', 'agla'),
#  ('agama', 'amaga'),
#  ('raga', 'agar'),
#  ('agger', 'regga'),
#  ('agib', 'biga'),
#  ('agrom', 'morga'),
#  ('agust', 'tsuga'),
#  ('ha', 'ah'),
#  ('moha', 'ahom'),
#  ('tha', 'aht'),
#  ('aider', 'redia'),
#  ('aile', 'elia'),
#  ('ima', 'ami'),
#  ('ria', 'air'),
#  ('aira', 'aria'),
#  ('eria', 'aire'),
#  ('ati', 'ita'),
#  ('ajar', 'raja'),
#  ('ak', 'ka'),
#  ('ako', 'oka'),
#  ('kua', 'auk'),
#  ('al', 'la'),
#  ('lana', 'anal'),
#  ('bal', 'lab'),
#  ('laban', 'nabal'),
#  ('alban', 'nabla'),
#  ('alem', 'mela'),
#  ('nael', 'lean'),
#  ('lina', 'anil'),
#  ('yalla', 'allay'),
#  ('alle', 'ella'),
#  ('allium', 'muilla'),
#  ('amla', 'alma'),
#  ('lamina', 'animal'),
#  ('dola', 'alod'),
#  ('lowa', 'awol'),
#  ('lap', 'pal'),
#  ('lat', 'tal'),
#  ('ma', 'am'),
#  ('apama', 'amapa'),
#  ('rama', 'amar'),
#  ('diorama', 'amaroid'),
#  ('assam', 'massa'),
#  ('amene', 'enema'),
#  ('ulema', 'amelu'),
#  ('enam', 'mane'),
#  ('nema', 'amen'),
#  ('amex', 'xema'),
#  ('amiced', 'decima'),
#  ('amil', 'lima'),
#  ('naim', 'mian'),
#  ('amir', 'rima'),
#  ('soma', 'amos'),
#  ('mat', 'tam'),
#  ('amunam', 'manuma'),
#  ('may', 'yam'),
#  ('na', 'an'),
#  ('aracana', 'anacara'),
#  ('mana', 'anam'),
#  ('anan', 'nana'),
#  ('asana', 'anasa'),
#  ('anat', 'tana'),
#  ('yana', 'anay'),
#  ('edna', 'ande'),
#  ('rogan', 'nagor'),
#  ('nias', 'sain'),
#  ('sina', 'anis'),
#  ('annam', 'manna'),
#  ('anon', 'nona'),
#  ('tan', 'nat'),
#  ('neat', 'taen'),
#  ('etna', 'ante'),
#  ('tuan', 'naut'),
#  ('nay', 'yan'),
#  ('trapa', 'apart'),
#  ('apod', 'dopa'),
#  ('tap', 'pat'),
#  ('supa', 'apus'),
#  ('ra', 'ar'),
#  ('bara', 'arab'),
#  ('daer', 'read'),
#  ('argas', 'sagra'),
#  ('regal', 'lager'),
#  ('rial', 'lair'),
#  ('liar', 'rail'),
#  ('aril', 'lira'),
#  ('ark', 'kra'),
#  ('ram', 'mar'),
#  ('nar', 'ran'),
#  ('aro', 'ora'),
#  ('sarra', 'arras'),
#  ('tracer', 'recart'),
#  ('sirrah', 'harris'),
#  ('tar', 'rat'),
#  ('tra', 'art'),
#  ('artamus', 'sumatra'),
#  ('ura', 'aru'),
#  ('arum', 'mura'),
#  ('ray', 'yar'),
#  ('rayan', 'nayar'),
#  ('lyra', 'aryl'),
#  ('sa', 'as'),
#  ('kasa', 'asak'),
#  ('mesa', 'asem'),
#  ('kras', 'sark'),
#  ('asor', 'rosa'),
#  ('ta', 'at'),
#  ('pata', 'atap'),
#  ('eat', 'tae'),
#  ('eta', 'ate'),
#  ('seta', 'ates'),
#  ('atip', 'pita'),
#  ('sita', 'atis'),
#  ('salta', 'atlas'),
#  ('teal', 'laet'),
#  ('leat', 'tael'),
#  ('atokal', 'lakota'),
#  ('laud', 'dual'),
#  ('aulu', 'ulua'),
#  ('aute', 'etua'),
#  ('lava', 'aval'),
#  ('eva', 'ave'),
#  ('diva', 'avid'),
#  ('avis', 'siva'),
#  ('avo', 'ova'),
#  ('wa', 'aw'),
#  ('awat', 'tawa'),
#  ('wad', 'daw'),
#  ('wan', 'naw'),
#  ('axon', 'noxa'),
#  ('ay', 'ya'),
#  ('haya', 'ayah'),
#  ('cab', 'bac'),
#  ('dab', 'bad'),
#  ('bag', 'gab'),
#  ('bam', 'mab'),
#  ('nab', 'ban'),
#  ('knab', 'bank'),
#  ('rab', 'bar'),
#  ('brab', 'barb'),
#  ('drab', 'bard'),
#  ('sab', 'bas'),
#  ('bats', 'stab'),
#  ('bat', 'tab'),
#  ('batik', 'kitab'),
#  ('baw', 'wab'),
#  ('deb', 'bed'),
#  ('beid', 'dieb'),
#  ('elbert', 'treble'),
#  ('neb', 'ben'),
#  ('reb', 'ber'),
#  ('bid', 'dib'),
#  ('gib', 'big'),
#  ('mib', 'bim'),
#  ('bin', 'nib'),
#  ('bird', 'drib'),
#  ('sib', 'bis'),
#  ('bit', 'tib'),
#  ('blub', 'bulb'),
#  ('cabob', 'bobac'),
#  ('bod', 'dob'),
#  ('bood', 'doob'),
#  ('bog', 'gob'),
#  ('bohor', 'rohob'),
#  ('lobo', 'obol'),
#  ('mob', 'bom'),
#  ('nob', 'bon'),
#  ('knob', 'bonk'),
#  ('pob', 'bop'),
#  ('rob', 'bor'),
#  ('borer', 'rerob'),
#  ('brog', 'gorb'),
#  ('bos', 'sob'),
#  ('wob', 'bow'),
#  ('brag', 'garb'),
#  ('bray', 'yarb'),
#  ('brey', 'yerb'),
#  ('brut', 'turb'),
#  ('trub', 'burt'),
#  ('rebut', 'tuber'),
#  ('dub', 'bud'),
#  ('bun', 'nub'),
#  ('bunk', 'knub'),
#  ('rub', 'bur'),
#  ('burd', 'drub'),
#  ('burg', 'grub'),
#  ('rubor', 'robur'),
#  ('rebus', 'suber'),
#  ('bus', 'sub'),
#  ('but', 'tub'),
#  ('dace', 'ecad'),
#  ('cal', 'lac'),
#  ('mac', 'cam'),
#  ('sumac', 'camus'),
#  ('cap', 'pac'),
#  ('decap', 'paced'),
#  ('recap', 'pacer'),
#  ('caw', 'wac'),
#  ('spec', 'ceps'),
#  ('cit', 'tic'),
#  ('clat', 'talc'),
#  ('decal', 'laced'),
#  ('cod', 'doc'),
#  ('orc', 'cro'),
#  ('cor', 'roc'),
#  ('soc', 'cos'),
#  ('marc', 'cram'),
#  ('cure', 'eruc'),
#  ('gad', 'dag'),
#  ('sgad', 'dags'),
#  ('dah', 'had'),
#  ('dial', 'laid'),
#  ('kedar', 'radek'),
#  ('lad', 'dal'),
#  ('dam', 'mad'),
#  ('damon', 'nomad'),
#  ('ladin', 'nidal'),
#  ('pad', 'dap'),
#  ('rad', 'dar'),
#  ('daraf', 'farad'),
#  ('darg', 'grad'),
#  ('ranid', 'dinar'),
#  ('darts', 'strad'),
#  ('darter', 'retrad'),
#  ('trader', 'redart'),
#  ('das', 'sad'),
#  ('detar', 'rated'),
#  ('de', 'ed'),
#  ('meed', 'deem'),
#  ('deep', 'peed'),
#  ('deer', 'reed'),
#  ('ged', 'deg'),
#  ('led', 'del'),
#  ('fled', 'delf'),
#  ('timed', 'demit'),
#  ('ned', 'den'),
#  ('depoh', 'hoped'),
#  ('tressed', 'dessert'),
#  ('leud', 'duel'),
#  ('devil', 'lived'),
#  ('dew', 'wed'),
#  ('rewed', 'dewer'),
#  ('dey', 'yed'),
#  ('id', 'di'),
#  ('morbid', 'dibrom'),
#  ('reid', 'dier'),
#  ('tide', 'edit'),
#  ('dig', 'gid'),
#  ('dilo', 'olid'),
#  ('mid', 'dim'),
#  ('dimit', 'timid'),
#  ('nid', 'din'),
#  ('enid', 'dine'),
#  ('dis', 'sid'),
#  ('dit', 'tid'),
#  ('do', 'od'),
#  ('ode', 'edo'),
#  ('god', 'dog'),
#  ('lod', 'dol'),
#  ('elod', 'dole'),
#  ('mod', 'dom'),
#  ('don', 'nod'),
#  ('dool', 'lood'),
#  ('mood', 'doom'),
#  ('mooder', 'redoom'),
#  ('rood', 'door'),
#  ('dop', 'pod'),
#  ('rod', 'dor'),
#  ('dorp', 'prod'),
#  ('sod', 'dos'),
#  ('tod', 'dot'),
#  ('dow', 'wod'),
#  ('drail', 'liard'),
#  ('draw', 'ward'),
#  ('reward', 'drawer'),
#  ('redraw', 'warder'),
#  ('drow', 'word'),
#  ('dug', 'gud'),
#  ('dum', 'mud'),
#  ('pud', 'dup'),
#  ('nae', 'ean'),
#  ('notice', 'eciton'),
#  ('lee', 'eel'),
#  ('eer', 'ree'),
#  ('egol', 'loge'),
#  ('he', 'eh'),
#  ('elaps', 'spale'),
#  ('nifle', 'elfin'),
#  ('haole', 'eloah'),
#  ('noel', 'leon'),
#  ('lone', 'enol'),
#  ('spole', 'elops'),
#  ('lees', 'seel'),
#  ('revel', 'lever'),
#  ('em', 'me'),
#  ('lime', 'emil'),
#  ('mime', 'emim'),
#  ('imer', 'remi'),
#  ('emir', 'rime'),
#  ('time', 'emit'),
#  ('emu', 'ume'),
#  ('en', 'ne'),
#  ('romane', 'enamor'),
#  ('reman', 'namer'),
#  ('fine', 'enif'),
#  ('wone', 'enow'),
#  ('esne', 'ense'),
#  ('nevoy', 'yoven'),
#  ('epos', 'sope'),
#  ('re', 'er'),
#  ('ger', 'reg'),
#  ('reen', 'neer'),
#  ('eros', 'sore'),
#  ('retier', 'reiter'),
#  ('rees', 'seer'),
#  ('es', 'se'),
#  ('evan', 'nave'),
#  ('neve', 'even'),
#  ('ever', 'reve'),
#  ('live', 'evil'),
#  ('ey', 'ye'),
#  ('nye', 'eyn'),
#  ('fiar', 'raif'),
#  ('reef', 'feer'),
#  ('feil', 'lief'),
#  ('nef', 'fen'),
#  ('fi', 'if'),
#  ('gif', 'fig'),
#  ('welf', 'flew'),
#  ('golf', 'flog'),
#  ('wolf', 'flow'),
#  ('reflow', 'wolfer'),
#  ('of', 'fo'),
#  ('loof', 'fool'),
#  ('foots', 'stoof'),
#  ('fro', 'orf'),
#  ('gaj', 'jag'),
#  ('lag', 'gal'),
#  ('gam', 'mag'),
#  ('gan', 'nag'),
#  ('gangan', 'nagnag'),
#  ('gnat', 'tang'),
#  ('gar', 'rag'),
#  ('rang', 'gnar'),
#  ('gas', 'sag'),
#  ('gat', 'tag'),
#  ('gater', 'retag'),
#  ('wag', 'gaw'),
#  ('wang', 'gnaw'),
#  ('zag', 'gaz'),
#  ('leg', 'gel'),
#  ('gelder', 'redleg'),
#  ('gem', 'meg'),
#  ('seg', 'ges'),
#  ('teg', 'get'),
#  ('mig', 'gim'),
#  ('nig', 'gin'),
#  ('gip', 'pig'),
#  ('trig', 'girt'),
#  ('git', 'tig'),
#  ('go', 'og'),
#  ('gol', 'log'),
#  ('reflog', 'golfer'),
#  ('gon', 'nog'),
#  ('rog', 'gor'),
#  ('sog', 'gos'),
#  ('tog', 'got'),
#  ('upgo', 'ogpu'),
#  ('gul', 'lug'),
#  ('plug', 'gulp'),
#  ('mug', 'gum'),
#  ('gup', 'pug'),
#  ('rug', 'gur'),
#  ('trug', 'gurt'),
#  ('gut', 'tug'),
#  ('hakam', 'makah'),
#  ('hallan', 'nallah'),
#  ('mah', 'ham'),
#  ('pah', 'hap'),
#  ('trah', 'hart'),
#  ('haw', 'wah'),
#  ('hay', 'yah'),
#  ('reh', 'her'),
#  ('oh', 'ho'),
#  ('pooh', 'hoop'),
#  ('hop', 'poh'),
#  ('obi', 'ibo'),
#  ('ni', 'in'),
#  ('retin', 'niter'),
#  ('tennis', 'sinnet'),
#  ('nori', 'iron'),
#  ('kori', 'irok'),
#  ('is', 'si'),
#  ('sisi', 'isis'),
#  ('ti', 'it'),
#  ('iten', 'neti'),
#  ('reit', 'tier'),
#  ('timo', 'omit'),
#  ('jar', 'raj'),
#  ('jat', 'taj'),
#  ('nak', 'kan'),
#  ('kanap', 'panak'),
#  ('kanat', 'tanak'),
#  ('lark', 'kral'),
#  ('kay', 'yak'),
#  ('leek', 'keel'),
#  ('keep', 'peek'),
#  ('kees', 'seek'),
#  ('kip', 'pik'),
#  ('polk', 'klop'),
#  ('pank', 'knap'),
#  ('kran', 'nark'),
#  ('knar', 'rank'),
#  ('tink', 'knit'),
#  ('tonk', 'knot'),
#  ('tunk', 'knut'),
#  ('ok', 'ko'),
#  ('kor', 'rok'),
#  ('sok', 'kos'),
#  ('kuar', 'rauk'),
#  ('mal', 'lam'),
#  ('nopal', 'lapon'),
#  ('palp', 'plap'),
#  ('sural', 'larus'),
#  ('las', 'sal'),
#  ('lias', 'sail'),
#  ('lasso', 'ossal'),
#  ('leep', 'peel'),
#  ('leer', 'reel'),
#  ('leet', 'teel'),
#  ('leper', 'repel'),
#  ('paler', 'relap'),
#  ('ler', 'rel'),
#  ('leveler', 'relevel'),
#  ('levir', 'rivel'),
#  ('neil', 'lien'),
#  ('mil', 'lim'),
#  ('nil', 'lin'),
#  ('noil', 'lion'),
#  ('sunil', 'linus'),
#  ('lis', 'sil'),
#  ('lit', 'til'),
#  ('llew', 'well'),
#  ('malo', 'olam'),
#  ('lois', 'siol'),
#  ('loom', 'mool'),
#  ('loop', 'pool'),
#  ('loot', 'tool'),
#  ('looter', 'retool'),
#  ('pol', 'lop'),
#  ('lot', 'tol'),
#  ('lwo', 'owl'),
#  ('man', 'nam'),
#  ('senam', 'manes'),
#  ('oam', 'mao'),
#  ('map', 'pam'),
#  ('tram', 'mart'),
#  ('mas', 'sam'),
#  ('stam', 'mats'),
#  ('teem', 'meet'),
#  ('remeet', 'teemer'),
#  ('timer', 'remit'),
#  ('meter', 'retem'),
#  ('wem', 'mew'),
#  ('ohm', 'mho'),
#  ('mias', 'saim'),
#  ('nim', 'min'),
#  ('mir', 'rim'),
#  ('om', 'mo'),
#  ('mools', 'sloom'),
#  ('moor', 'room'),
#  ('toom', 'moot'),
#  ('pom', 'mop'),
#  ('mot', 'tom'),
#  ('yom', 'moy'),
#  ('um', 'mu'),
#  ('sum', 'mus'),
#  ('my', 'ym'),
#  ('nahor', 'rohan'),
#  ('zaman', 'namaz'),
#  ('pan', 'nap'),
#  ('nasus', 'susan'),
#  ('nedder', 'redden'),
#  ('peen', 'neep'),
#  ('neet', 'teen'),
#  ('pen', 'nep'),
#  ('neper', 'repen'),
#  ('net', 'ten'),
#  ('oven', 'nevo'),
#  ('new', 'wen'),
#  ('pin', 'nip'),
#  ('nit', 'tin'),
#  ('no', 'on'),
#  ('nonet', 'tenon'),
#  ('poon', 'noop'),
#  ('nor', 'ron'),
#  ('ton', 'not'),
#  ('now', 'won'),
#  ('noy', 'yon'),
#  ('nu', 'un'),
#  ('nut', 'tun'),
#  ('oat', 'tao'),
#  ('top', 'pot'),
#  ('ro', 'or'),
#  ('tor', 'rot'),
#  ('roy', 'yor'),
#  ('os', 'so'),
#  ('suto', 'otus'),
#  ('ow', 'wo'),
#  ('par', 'rap'),
#  ('part', 'trap'),
#  ('prat', 'tarp'),
#  ('spat', 'taps'),
#  ('wap', 'paw'),
#  ('pay', 'yap'),
#  ('per', 'rep'),
#  ('pir', 'rip'),
#  ('tip', 'pit'),
#  ('plup', 'pulp'),
#  ('toop', 'poot'),
#  ('report', 'troper'),
#  ('tops', 'spot'),
#  ('toper', 'repot'),
#  ('wop', 'pow'),
#  ('prut', 'turp'),
#  ('pu', 'up'),
#  ('pus', 'sup'),
#  ('tup', 'put'),
#  ('ras', 'sar'),
#  ('war', 'raw'),
#  ('redrawer', 'rewarder'),
#  ('teer', 'reet'),
#  ('sier', 'reis'),
#  ('tinker', 'reknit'),
#  ('rennet', 'tenner'),
#  ('rewet', 'tewer'),
#  ('rotanev', 'venator'),
#  ('rus', 'sur'),
#  ('rut', 'tur'),
#  ('saw', 'was'),
#  ('twas', 'sawt'),
#  ('swat', 'taws'),
#  ('yas', 'say'),
#  ('wes', 'sew'),
#  ('yes', 'sey'),
#  ('wels', 'slew'),
#  ('wots', 'stow'),
#  ('traps', 'spart'),
#  ('stut', 'tuts'),
#  ('yaws', 'sway'),
#  ('vat', 'tav'),
#  ('wat', 'taw'),
#  ('tay', 'yat'),
#  ('wet', 'tew'),
#  ('trot', 'tort'),
#  ('wot', 'tow'),
#  ('yot', 'toy'),
#  ('wort', 'trow'),
#  ('ut', 'tu'),
#  ('way', 'yaw'),
#  ('wey', 'yew'),
#  ('woy', 'yow')]
